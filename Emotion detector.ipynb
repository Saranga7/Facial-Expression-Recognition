# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from keras.layers import Conv2D,MaxPooling2D
import os
# Out:
# Using TensorFlow backend.
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Saranga\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
num_classes = 5
img_rows,img_cols = 48,48
batch_size = 32
epochs=10

# %%
img_size=[48,48]

# %%
train_data_dir = 'train'
validation_data_dir = 'validation'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                    rotation_range=30,
                                    shear_range=0.3,
                                    zoom_range=0.3,
                                    width_shift_range=0.4,
                                    height_shift_range=0.4,
                                    horizontal_flip=True,
                                    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_set = train_datagen.flow_from_directory(
train_data_dir,
color_mode='grayscale',
target_size=(img_rows,img_cols),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)

validation_set = validation_datagen.flow_from_directory(
validation_data_dir,
color_mode='grayscale',
target_size=(img_rows,img_cols),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)
# Out:
# Found 24256 images belonging to 5 classes.
# Found 3006 images belonging to 5 classes.

# %%
model = Sequential()

# Block-1

model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-2 

model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-3

model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-4 

model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-5

model.add(Flatten())
model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-6

model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-7

model.add(Dense(num_classes,kernel_initializer='he_normal'))
model.add(Activation('softmax'))

print(model.summary())

from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint('Emotion_little_vgg2.h5',
                             monitor='val_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks = [checkpoint,reduce_lr]

model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics=['accuracy'])

nb_train_samples = 24256
nb_validation_samples = 3006
epochs=25
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 48, 48, 32)        320
# _________________________________________________________________
# activation_34 (Activation)   (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 48, 48, 32)        9248
# _________________________________________________________________
# activation_35 (Activation)   (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_36 (Activation)   (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# activation_37 (Activation)   (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# activation_38 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_39 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 6, 6, 256)         295168
# _________________________________________________________________
# activation_40 (Activation)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 6, 6, 256)         590080
# _________________________________________________________________
# activation_41 (Activation)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                147520
# _________________________________________________________________
# activation_42 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# activation_43 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 325
# _________________________________________________________________
# activation_44 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,328,037
# Trainable params: 1,325,861
# Non-trainable params: 2,176
# _________________________________________________________________
# None

# %%
history=model.fit_generator(
                train_set,
                steps_per_epoch=nb_train_samples//batch_size,
                epochs=epochs,
                callbacks=callbacks,
                validation_data=validation_set,
                validation_steps=nb_validation_samples//batch_size)
# Out:
# Epoch 1/25
# 758/758 [==============================] - 154s 203ms/step - loss: 1.8222 - accuracy: 0.2388 - val_loss: 1.4730 - val_accuracy: 0.2907
#
# Epoch 00001: val_accuracy improved from -inf to 0.29066, saving model to Emotion_little_vgg2.h5
# Epoch 2/25
# 758/758 [==============================] - 150s 197ms/step - loss: 1.5648 - accuracy: 0.2898 - val_loss: 1.5612 - val_accuracy: 0.3067
#
# Epoch 00002: val_accuracy improved from 0.29066 to 0.30666, saving model to Emotion_little_vgg2.h5
# Epoch 3/25
# 758/758 [==============================] - 177s 234ms/step - loss: 1.5455 - accuracy: 0.3005 - val_loss: 1.4876 - val_accuracy: 0.3255
#
# Epoch 00003: val_accuracy improved from 0.30666 to 0.32549, saving model to Emotion_little_vgg2.h5
# Epoch 4/25
# 758/758 [==============================] - 1256s 2s/step - loss: 1.5072 - accuracy: 0.3292 - val_loss: 1.1819 - val_accuracy: 0.3790
#
# Epoch 00004: val_accuracy improved from 0.32549 to 0.37895, saving model to Emotion_little_vgg2.h5
# Epoch 5/25
# 758/758 [==============================] - 325s 429ms/step - loss: 1.4231 - accuracy: 0.3849 - val_loss: 1.3519 - val_accuracy: 0.4630
#
# Epoch 00005: val_accuracy improved from 0.37895 to 0.46301, saving model to Emotion_little_vgg2.h5
# Epoch 6/25
# 758/758 [==============================] - 90s 119ms/step - loss: 1.3212 - accuracy: 0.4459 - val_loss: 1.1810 - val_accuracy: 0.4966
#
# Epoch 00006: val_accuracy improved from 0.46301 to 0.49664, saving model to Emotion_little_vgg2.h5
# Epoch 7/25
# 758/758 [==============================] - 88s 116ms/step - loss: 1.2561 - accuracy: 0.4831 - val_loss: 0.9896 - val_accuracy: 0.5027
#
# Epoch 00007: val_accuracy improved from 0.49664 to 0.50269, saving model to Emotion_little_vgg2.h5
# Epoch 8/25
# 758/758 [==============================] - 89s 118ms/step - loss: 1.2044 - accuracy: 0.5119 - val_loss: 1.5668 - val_accuracy: 0.5259
#
# Epoch 00008: val_accuracy improved from 0.50269 to 0.52589, saving model to Emotion_little_vgg2.h5
# Epoch 9/25
# 758/758 [==============================] - 89s 118ms/step - loss: 1.1686 - accuracy: 0.5295 - val_loss: 1.0930 - val_accuracy: 0.5363
#
# Epoch 00009: val_accuracy improved from 0.52589 to 0.53631, saving model to Emotion_little_vgg2.h5
# Epoch 10/25
# 758/758 [==============================] - 89s 118ms/step - loss: 1.1428 - accuracy: 0.5401 - val_loss: 1.7239 - val_accuracy: 0.5377
#
# Epoch 00010: val_accuracy improved from 0.53631 to 0.53766, saving model to Emotion_little_vgg2.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/25
# 758/758 [==============================] - 89s 117ms/step - loss: 1.0959 - accuracy: 0.5665 - val_loss: 1.0388 - val_accuracy: 0.5760
#
# Epoch 00011: val_accuracy improved from 0.53766 to 0.57599, saving model to Emotion_little_vgg2.h5
# Epoch 12/25
# 758/758 [==============================] - 89s 117ms/step - loss: 1.0760 - accuracy: 0.5740 - val_loss: 0.8014 - val_accuracy: 0.5689
#
# Epoch 00012: val_accuracy did not improve from 0.57599
# Epoch 13/25
# 758/758 [==============================] - 90s 118ms/step - loss: 1.0542 - accuracy: 0.5871 - val_loss: 1.6764 - val_accuracy: 0.5857
#
# Epoch 00013: val_accuracy improved from 0.57599 to 0.58574, saving model to Emotion_little_vgg2.h5
# Epoch 14/25
# 758/758 [==============================] - 90s 119ms/step - loss: 1.0519 - accuracy: 0.5848 - val_loss: 0.8902 - val_accuracy: 0.5928
#
# Epoch 00014: val_accuracy improved from 0.58574 to 0.59280, saving model to Emotion_little_vgg2.h5
# Epoch 15/25
# 758/758 [==============================] - 89s 117ms/step - loss: 1.0503 - accuracy: 0.5849 - val_loss: 1.0489 - val_accuracy: 0.5915
#
# Epoch 00015: val_accuracy did not improve from 0.59280
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 16/25
# 758/758 [==============================] - 97s 128ms/step - loss: 1.0307 - accuracy: 0.5934 - val_loss: 1.1489 - val_accuracy: 0.5955
#
# Epoch 00016: val_accuracy improved from 0.59280 to 0.59549, saving model to Emotion_little_vgg2.h5
# Epoch 17/25
# 758/758 [==============================] - 90s 119ms/step - loss: 1.0236 - accuracy: 0.5956 - val_loss: 1.5447 - val_accuracy: 0.6012
#
# Epoch 00017: val_accuracy improved from 0.59549 to 0.60121, saving model to Emotion_little_vgg2.h5
# Epoch 18/25
# 758/758 [==============================] - 90s 119ms/step - loss: 1.0295 - accuracy: 0.5987 - val_loss: 1.4166 - val_accuracy: 0.5945
#
# Epoch 00018: val_accuracy did not improve from 0.60121
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 19/25
# 758/758 [==============================] - 94s 124ms/step - loss: 1.0273 - accuracy: 0.6000 - val_loss: 1.0834 - val_accuracy: 0.5854
#
# Epoch 00019: val_accuracy did not improve from 0.60121
# Epoch 20/25
# 758/758 [==============================] - 138s 182ms/step - loss: 1.0289 - accuracy: 0.5935 - val_loss: 1.0945 - val_accuracy: 0.6042
#
# Epoch 00020: val_accuracy improved from 0.60121 to 0.60424, saving model to Emotion_little_vgg2.h5
# Epoch 21/25
# 758/758 [==============================] - 124s 164ms/step - loss: 1.0212 - accuracy: 0.6005 - val_loss: 0.9503 - val_accuracy: 0.5888
#
# Epoch 00021: val_accuracy did not improve from 0.60424
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 22/25
# 758/758 [==============================] - 102s 134ms/step - loss: 1.0249 - accuracy: 0.6045 - val_loss: 1.2690 - val_accuracy: 0.6042
#
# Epoch 00022: val_accuracy did not improve from 0.60424
# Epoch 23/25
# 758/758 [==============================] - 118s 156ms/step - loss: 1.0221 - accuracy: 0.6017 - val_loss: 1.6705 - val_accuracy: 0.5837
#
# Epoch 00023: val_accuracy did not improve from 0.60424
# Epoch 24/25
# 758/758 [==============================] - 162s 213ms/step - loss: 1.0155 - accuracy: 0.6044 - val_loss: 0.6277 - val_accuracy: 0.6106
#
# Epoch 00024: val_accuracy improved from 0.60424 to 0.61063, saving model to Emotion_little_vgg2.h5
# Epoch 25/25
# 758/758 [==============================] - 119s 156ms/step - loss: 1.0239 - accuracy: 0.5988 - val_loss: 1.0737 - val_accuracy: 0.5857
#
# Epoch 00025: val_accuracy did not improve from 0.61063
